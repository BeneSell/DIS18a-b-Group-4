# %%
for abstract in abstracts_with_one_perc:
    text = abstract["Abstract"]["AbstractText"][0]
    bacterial_match = re.search(r"<i>(.*?)</i>", text)
    if bacterial_match:
        bacterial_name = bacterial_match.group(1)
    else:
        bacterial_name = "Unknown"
    gc_match = re.search(r"([\d\.]+\%)", text)
    if gc_match:
        gc_content = gc_match.group(1)
    else:
        gc_content = "Unknown"
    print(f"{bacterial_name} has a GC content of {gc_content}")
# Out:
# Unknown has a GC content of 43.88%
# Unknown has a GC content of 56%
# Unknown has a GC content of 53.50%
# Unknown has a GC content of 51.68%
# Martelella soudanensis has a GC content of Unknown
# Unknown has a GC content of Unknown
# E. coli has a GC content of 7.4%
# Oceanobacillus jordanicus has a GC content of 39.09%
# Lactobacillus rhamnosus has a GC content of Unknown
# Pediococcus pentosaceus has a GC content of Unknown
# Xanthomonas oryzae has a GC content of 63.7%
# Bacillus has a GC content of 41.41%
# Streptomyces has a GC content of 71.80%
# Unknown has a GC content of 39.2%
# Methylocystis has a GC content of Unknown
# Paenibacillus has a GC content of 46%
# Enterococcus faecalis has a GC content of Unknown
# Enterobacter roggenkampii has a GC content of 56.16%
# Unknown has a GC content of Unknown
# Unknown has a GC content of 39%
# Unknown has a GC content of 0.9%
# Unknown has a GC content of 27.6%
# Unknown has a GC content of 53.8%
# Pseudarthrobacter phenanthrenivorans has a GC content of 65.30%
# Unknown has a GC content of 64%
# Unknown has a GC content of Unknown
# Methanococcus maripaludis has a GC content of 94%
# Unknown has a GC content of 59.2%
# 'Cellulomonas timonensis' has a GC content of 72.42%
# Acidovorax citrulli has a GC content of 58.7%
# Unknown has a GC content of 71%
# Unknown has a GC content of 200%
# Methylobacterium radiotolerans has a GC content of 70.5%
# Enterococcus, Staphylococcus, Streptococcus, Serratia, Klebsiella has a GC content of 75%
# Lactobacillus murinus has a GC content of 39.6%
# Unknown has a GC content of 68.66%
# Unknown has a GC content of 95%
# Unknown has a GC content of Unknown
# Unknown has a GC content of 34.4%
# Unknown has a GC content of Unknown
# Unknown has a GC content of 67.81%
# Unknown has a GC content of 44.8%
# Unknown has a GC content of 52.46%
# Unknown has a GC content of 2%

# %%
from Bio import Entrez
import re

Entrez.email = "emirhan.acikgoez@hotmail.com"  # Always tell NCBI who you are

# Search PubMed for articles with "GC-content" in the title
abstracts_with_gc = []
for i in range(0, 200, 20):
    handle = Entrez.esearch(db="pubmed", term="GC AND content AND bacterial[Title]", retstart=i, retmax=20)
    record = Entrez.read(handle)
    ids = record["IdList"]
    # Process the IDs

    # Get the list of article IDs
    article_ids = record["IdList"]

    # Fetch the abstracts for the articles
    handle = Entrez.efetch(db="pubmed", id=article_ids, rettype="abstract")
    records = Entrez.read(handle)

    # Parse the abstracts
    for record in records["PubmedArticle"]:
        try:
            temp_record = record["MedlineCitation"]["Article"]
            abstract = temp_record["Abstract"]["AbstractText"][0]
            gc_match = re.search(r"([\d\.]+\%)", abstract)
            bacterial_match = re.search(r"<i>(.*?)</i>", abstract)
            if gc_match and bacterial_match:
                gc_content = gc_match.group(1)
                bacterial_name = bacterial_match.group(1)
                abstracts_with_gc.append((bacterial_name, gc_content))
        except KeyError:
            print("No abstract available")

# Print the bacterial names and their corresponding GC content percentages
for bacterial_name, gc_content in abstracts_with_gc:
    print(f"{bacterial_name} has a GC content of {gc_content}")
# Out:
# No abstract available
# Xanthomonas oryzae has a GC content of 80%
# Geminicoccaceae has a GC content of 96.9%
# Triticum aestivum has a GC content of 5%
# Petroselinum crispum has a GC content of 99.93%
# Brachybacterium muris has a GC content of 99.5%
# E. coli has a GC content of 7.4%
# Peptostreptococcus anaerobius has a GC content of 96.2%
# Oceanobacillus jordanicus has a GC content of 39.09%
# Acidobacteria has a GC content of 29.2%
# Thymus vulgaris has a GC content of 100%
# Oe has a GC content of 93.3%
# Xanthomonas oryzae has a GC content of 63.7%
# Bacillus has a GC content of 41.41%
# . Neobacillus massiliamazoniensis has a GC content of 98.32%
# Ralstonia solanacearum has a GC content of 68%
# Actinomycetales has a GC content of 94.73%
# Schleiferiaceae has a GC content of 46.6%
# Streptomyces has a GC content of 71.80%
# Paenibacillus has a GC content of 46%
# Enterobacter roggenkampii has a GC content of 56.16%
# Erysipelothrix rhusiopathiae has a GC content of 36.49%
# Pseudarthrobacter phenanthrenivorans has a GC content of 65.30%
# Allium fistulosum has a GC content of 99.72%
# n has a GC content of 5%
# Acidobacteria has a GC content of 57%
# Bacillus has a GC content of 35.23%
# Dielma fastidiosa has a GC content of 93.2%
# Bacillus velezensis has a GC content of 46.5%
# Agaricus bisporus. has a GC content of 55%
# Alteromonadales bacterium has a GC content of 53%
# Methanococcus maripaludis has a GC content of 94%
# Mauritia flexuosa has a GC content of 89.81%
# Xanthomonas euvesicatoria has a GC content of 62.9%
# 'Cellulomonas timonensis' has a GC content of 72.42%
# Acidovorax citrulli has a GC content of 58.7%
# Methylobacterium radiotolerans has a GC content of 70.5%
# Enterococcus, Staphylococcus, Streptococcus, Serratia, Klebsiella has a GC content of 75%
# Lactobacillus murinus has a GC content of 39.6%
# Rubeoparvulum massiliense has a GC content of 92%

# %%
#Xanthomonas  Hat eine große Range an GC content
#Reicht es, wenn wir einen konkreten Wert aus einer Studie ziehen, oder müssen wir die Range ermitteln?

# %%
from Bio import Entrez
import re

Entrez.email = "emirhan.acikgoez@hotmail.com"  # Always tell NCBI who you are

# Search PubMed for articles with "GC-content" in the title
abstracts_with_gc = []
for i in range(0, 200, 20):
    handle = Entrez.esearch(db="pubmed", term="GC AND content AND bacterial[Title]", retstart=i, retmax=20)
    record = Entrez.read(handle)
    ids = record["IdList"]
    # Process the IDs

    # Get the list of article IDs
    article_ids = record["IdList"]

    # Fetch the abstracts for the articles
    handle = Entrez.efetch(db="pubmed", id=article_ids, rettype="abstract")
    records = Entrez.read(handle)

    # Parse the abstracts
    for record in records["PubmedArticle"]:
        try:
            temp_record = record["MedlineCitation"]["Article"]
            abstract = temp_record["Abstract"]["AbstractText"][0]
            gc_match = re.search(r"([\d\.]+\%)", abstract)
            bacterial_match = re.search(r"<i>(.*?)</i>", abstract)
            if gc_match and bacterial_match:
                gc_content = gc_match.group(1)
                bacterial_name = bacterial_match.group(1)
                # Prompt the user to input whether the GC content value is correct or not
                correct = input(f"Is the GC content value '{gc_content}' correct for {bacterial_name}? (y/n) ")
                while correct.lower() not in ['y', 'n']:
                    correct = input("Invalid input. Please enter 'y' or 'n': ")
                if correct.lower() == 'y':
                    abstracts_with_gc.append((bacterial_name, gc_content))
        except KeyError:y
            print("No abstract available")

# Print the bacterial names and their corresponding GC content percentages
for bacterial_name, gc_content in abstracts_with_gc:
    print(f"{bacterial_name} has a GC content of {gc_content}")
# Out:
# Is the GC content value '80%' correct for Xanthomonas oryzae? (y/n) y
# Is the GC content value '96.9%' correct for Geminicoccaceae? (y/n) y
# Is the GC content value '5%' correct for Triticum aestivum? (y/n) n
# Is the GC content value '99.93%' correct for Petroselinum crispum? (y/n) y
# Is the GC content value '99.5%' correct for Brachybacterium muris? (y/n) n
# Is the GC content value '7.4%' correct for E. coli? (y/n) y
# Is the GC content value '96.2%' correct for Peptostreptococcus anaerobius? (y/n) n
# Is the GC content value '39.09%' correct for Oceanobacillus jordanicus? (y/n) y
# Is the GC content value '29.2%' correct for Acidobacteria? (y/n) y
# Is the GC content value '100%' correct for Thymus vulgaris? (y/n) y
# Is the GC content value '93.3%' correct for Oe? (y/n) y
# Is the GC content value '63.7%' correct for Xanthomonas oryzae? (y/n) y
# Is the GC content value '41.41%' correct for Bacillus? (y/n) y
# Is the GC content value '98.32%' correct for . Neobacillus massiliamazoniensis? (y/n) y
# Is the GC content value '68%' correct for Ralstonia solanacearum? (y/n) y
# Is the GC content value '94.73%' correct for Actinomycetales? (y/n) y
# Is the GC content value '46.6%' correct for Schleiferiaceae? (y/n) y
# Is the GC content value '71.80%' correct for Streptomyces? (y/n) y
# Is the GC content value '46%' correct for Paenibacillus? (y/n) y
# Is the GC content value '56.16%' correct for Enterobacter roggenkampii? (y/n) y
# Is the GC content value '36.49%' correct for Erysipelothrix rhusiopathiae? (y/n) y
# Is the GC content value '65.30%' correct for Pseudarthrobacter phenanthrenivorans? (y/n) y
# Is the GC content value '99.72%' correct for Allium fistulosum? (y/n) n
# Is the GC content value '5%' correct for n? (y/n) y
# Is the GC content value '57%' correct for Acidobacteria? (y/n) y
# Is the GC content value '35.23%' correct for Bacillus? (y/n) y
# Is the GC content value '93.2%' correct for Dielma fastidiosa? (y/n) y
# Is the GC content value '46.5%' correct for Bacillus velezensis? (y/n) y
# Is the GC content value '55%' correct for Agaricus bisporus.? (y/n) y
# Is the GC content value '53%' correct for Alteromonadales bacterium? (y/n) y
# Is the GC content value '94%' correct for Methanococcus maripaludis? (y/n) y
# Is the GC content value '89.81%' correct for Mauritia flexuosa? (y/n) y
# No abstract available
# Is the GC content value '62.9%' correct for Xanthomonas euvesicatoria? (y/n) y
# Is the GC content value '72.42%' correct for 'Cellulomonas timonensis'? (y/n) y
# Is the GC content value '58.7%' correct for Acidovorax citrulli? (y/n) y
# Is the GC content value '70.5%' correct for Methylobacterium radiotolerans? (y/n) y
# Is the GC content value '75%' correct for Enterococcus, Staphylococcus, Streptococcus, Serratia, Klebsiella? (y/n) n
# Is the GC content value '39.6%' correct for Lactobacillus murinus? (y/n) n
# Is the GC content value '92%' correct for Rubeoparvulum massiliense? (y/n) n
# Xanthomonas oryzae has a GC content of 80%
# Geminicoccaceae has a GC content of 96.9%
# Petroselinum crispum has a GC content of 99.93%
# E. coli has a GC content of 7.4%
# Oceanobacillus jordanicus has a GC content of 39.09%
# Acidobacteria has a GC content of 29.2%
# Thymus vulgaris has a GC content of 100%
# Oe has a GC content of 93.3%
# Xanthomonas oryzae has a GC content of 63.7%
# Bacillus has a GC content of 41.41%
# . Neobacillus massiliamazoniensis has a GC content of 98.32%
# Ralstonia solanacearum has a GC content of 68%
# Actinomycetales has a GC content of 94.73%
# Schleiferiaceae has a GC content of 46.6%
# Streptomyces has a GC content of 71.80%
# Paenibacillus has a GC content of 46%
# Enterobacter roggenkampii has a GC content of 56.16%
# Erysipelothrix rhusiopathiae has a GC content of 36.49%
# Pseudarthrobacter phenanthrenivorans has a GC content of 65.30%
# n has a GC content of 5%
# Acidobacteria has a GC content of 57%
# Bacillus has a GC content of 35.23%
# Dielma fastidiosa has a GC content of 93.2%
# Bacillus velezensis has a GC content of 46.5%
# Agaricus bisporus. has a GC content of 55%
# Alteromonadales bacterium has a GC content of 53%
# Methanococcus maripaludis has a GC content of 94%
# Mauritia flexuosa has a GC content of 89.81%
# Xanthomonas euvesicatoria has a GC content of 62.9%
# 'Cellulomonas timonensis' has a GC content of 72.42%
# Acidovorax citrulli has a GC content of 58.7%
# Methylobacterium radiotolerans has a GC content of 70.5%

# %%
from Bio import Entrez
import re

Entrez.email = "emirhan.acikgoez@hotmail.com"  # Always tell NCBI who you are

# Search PubMed for articles with "GC-content" in the title
abstracts_with_gc = []
for i in range(0, 200, 20):
    handle = Entrez.esearch(db="pubmed", term="GC AND content AND bacterial[Title]", retstart=i, retmax=20)
    record = Entrez.read(handle)
    ids = record["IdList"]
    # Process the IDs

    # Get the list of article IDs
    article_ids = record["IdList"]

    # Fetch the abstracts for the articles
    handle = Entrez.efetch(db="pubmed", id=article_ids, rettype="abstract")
    records = Entrez.read(handle)

    # Parse the abstracts
    for record in records["PubmedArticle"]:
        try:
            temp_record = record["MedlineCitation"]["Article"]
            abstract = temp_record["Abstract"]["AbstractText"][0]
            gc_match = re.search(r"([\d\.]+\%)", abstract)
            bacterial_match = re.search(r"<i>(.*?)</i>", abstract)
            doi = record['PubmedData']['ArticleIdList'][0] if 'ArticleIdList' in record['PubmedData'] else 'N/A'
            if gc_match and bacterial_match:
                gc_content = gc_match.group(1)
                bacterial_name = bacterial_match.group(1)
                # Prompt the user to input whether the GC content value is correct or not
                correct = input(f"Is the GC content value '{gc_content}' correct for {bacterial_name}? (y/n) ")
                while correct.lower() not in ['y', 'n']:
                    correct = input("Invalid input. Please enter 'y' or 'n': ")
                if correct.lower() == 'y':
                    abstracts_with_gc.append((bacterial_name, gc_content, doi))
        except KeyError:
            print("No abstract available")

# Print the bacterial names, their corresponding GC content percentages, and the DOI for each article
for bacterial_name, gc_content, doi in abstracts_with_gc:
    print(f"{bacterial_name} has a GC content of {gc_content} (DOI: {doi})")
# Out:
# Is the GC content value '80%' correct for Xanthomonas oryzae? (y/n) y
# Is the GC content value '96.9%' correct for Geminicoccaceae? (y/n) n
# Is the GC content value '5%' correct for Triticum aestivum? (y/n) n
# Is the GC content value '99.93%' correct for Petroselinum crispum? (y/n) n
# Is the GC content value '99.5%' correct for Brachybacterium muris? (y/n) n
# Is the GC content value '7.4%' correct for E. coli? (y/n) n
# Is the GC content value '96.2%' correct for Peptostreptococcus anaerobius? (y/n) n
# Is the GC content value '39.09%' correct for Oceanobacillus jordanicus? (y/n) n
# Is the GC content value '29.2%' correct for Acidobacteria? (y/n) n
# Is the GC content value '100%' correct for Thymus vulgaris? (y/n) n
# Is the GC content value '93.3%' correct for Oe? (y/n) n
# Is the GC content value '63.7%' correct for Xanthomonas oryzae? (y/n) n
# Is the GC content value '41.41%' correct for Bacillus? (y/n) n
# Is the GC content value '98.32%' correct for . Neobacillus massiliamazoniensis? (y/n) n
# Is the GC content value '68%' correct for Ralstonia solanacearum? (y/n) n
# Is the GC content value '94.73%' correct for Actinomycetales? (y/n) n
# Is the GC content value '46.6%' correct for Schleiferiaceae? (y/n) n
# Is the GC content value '71.80%' correct for Streptomyces? (y/n) n
# Is the GC content value '46%' correct for Paenibacillus? (y/n) n
# Is the GC content value '56.16%' correct for Enterobacter roggenkampii? (y/n) n
# Is the GC content value '36.49%' correct for Erysipelothrix rhusiopathiae? (y/n) n
# Is the GC content value '65.30%' correct for Pseudarthrobacter phenanthrenivorans? (y/n) n
# Is the GC content value '99.72%' correct for Allium fistulosum? (y/n) n
# Is the GC content value '5%' correct for n? (y/n) n
# Is the GC content value '57%' correct for Acidobacteria? (y/n) n
# Is the GC content value '35.23%' correct for Bacillus? (y/n) n
# Is the GC content value '93.2%' correct for Dielma fastidiosa? (y/n) n
# Is the GC content value '46.5%' correct for Bacillus velezensis? (y/n) n
# Is the GC content value '55%' correct for Agaricus bisporus.? (y/n) n
# Is the GC content value '53%' correct for Alteromonadales bacterium? (y/n) n
# Is the GC content value '94%' correct for Methanococcus maripaludis? (y/n) n
# Is the GC content value '89.81%' correct for Mauritia flexuosa? (y/n) n
# No abstract available
# Is the GC content value '62.9%' correct for Xanthomonas euvesicatoria? (y/n) n
# Is the GC content value '72.42%' correct for 'Cellulomonas timonensis'? (y/n) n
# Is the GC content value '58.7%' correct for Acidovorax citrulli? (y/n) n
# Is the GC content value '70.5%' correct for Methylobacterium radiotolerans? (y/n) n
# Is the GC content value '75%' correct for Enterococcus, Staphylococcus, Streptococcus, Serratia, Klebsiella? (y/n) n
# Is the GC content value '39.6%' correct for Lactobacillus murinus? (y/n) n
# Is the GC content value '92%' correct for Rubeoparvulum massiliense? (y/n) n
# Xanthomonas oryzae has a GC content of 80% (DOI: 37007514)

# %%
from Bio import Entrez
import re

Entrez.email = "emirhan.acikgoez@hotmail.com"  # Always tell NCBI who you are

# Search PubMed for articles with "GC-content" in the title
abstracts_with_gc = []
for i in range(0, 200, 20):
    handle = Entrez.esearch(db="pubmed", term="GC AND content AND bacterial[Title]", retstart=i, retmax=20)
    record = Entrez.read(handle)
    ids = record["IdList"]
    # Process the IDs

    # Get the list of article IDs
    article_ids = record["IdList"]

    # Fetch the abstracts for the articles
    handle = Entrez.efetch(db="pubmed", id=article_ids, rettype="abstract")
    records = Entrez.read(handle)

    # Parse the abstracts
    for record in records["PubmedArticle"]:
        try:
            temp_record = record["MedlineCitation"]["Article"]
            abstract = temp_record["Abstract"]["AbstractText"][0]
            gc_match = re.search(r"([\d\.]+\%)", abstract)
            bacterial_match = re.search(r"<i>(.*?)</i>", abstract)
            doi = record['PubmedData']['ArticleIdList'][0] if 'ArticleIdList' in record['PubmedData'] else 'N/A'
            if gc_match and bacterial_match:
                gc_content = gc_match.group(1)
                bacterial_name = bacterial_match.group(1)
                # Prompt the user to input whether the GC content value is correct or not
                print(f"DOI: {doi}")
                correct = input(f"Is the GC content value '{gc_content}' correct for {bacterial_name}? (y/n) ")
                while correct.lower() not in ['y', 'n']:
                    correct = input("Invalid input. Please enter 'y' or 'n': ")
                if correct.lower() == 'y':
                    abstracts_with_gc.append((bacterial_name, gc_content, doi))
        except KeyError:
            print("No abstract available")

# Print the bacterial names, their corresponding GC content percentages, and the DOI for each article
for bacterial_name, gc_content, doi in abstracts_with_gc:
    print(f"DOI: {doi}")
    print(f"{bacterial_name} has a GC content of {gc_content}")
# Out:
# DOI: 37007514
# Is the GC content value '80%' correct for Xanthomonas oryzae? (y/n) n
# DOI: 36386637
# Is the GC content value '96.9%' correct for Geminicoccaceae? (y/n) n
# DOI: 35698247
# Is the GC content value '5%' correct for Triticum aestivum? (y/n) n
# DOI: 35695838
# Is the GC content value '99.93%' correct for Petroselinum crispum? (y/n) n
# DOI: 35392139
# Is the GC content value '99.5%' correct for Brachybacterium muris? (y/n) n
# DOI: 35330182
# Is the GC content value '7.4%' correct for E. coli? (y/n) n
# DOI: 35313487
# Is the GC content value '96.2%' correct for Peptostreptococcus anaerobius? (y/n) n
# DOI: 35095268
# Is the GC content value '39.09%' correct for Oceanobacillus jordanicus? (y/n) n
# DOI: 35087491
# Is the GC content value '29.2%' correct for Acidobacteria? (y/n) n
# DOI: 35041305
# Is the GC content value '100%' correct for Thymus vulgaris? (y/n) n
# DOI: 34739370
# Is the GC content value '93.3%' correct for Oe? (y/n) n
# DOI: 34598657
# Is the GC content value '63.7%' correct for Xanthomonas oryzae? (y/n) n
# DOI: 34311561
# Is the GC content value '41.41%' correct for Bacillus? (y/n) n
# DOI: 34168882
# Is the GC content value '98.32%' correct for . Neobacillus massiliamazoniensis? (y/n) n
# DOI: 33911932
# Is the GC content value '68%' correct for Ralstonia solanacearum? (y/n) n
# DOI: 33854785
# Is the GC content value '94.73%' correct for Actinomycetales? (y/n) n
# DOI: 33847553
# Is the GC content value '46.6%' correct for Schleiferiaceae? (y/n) n
# DOI: 33707334
# Is the GC content value '71.80%' correct for Streptomyces? (y/n) n
# DOI: 33033124
# Is the GC content value '46%' correct for Paenibacillus? (y/n) n
# DOI: 32840429
# Is the GC content value '56.16%' correct for Enterobacter roggenkampii? (y/n) n
# DOI: 32512708
# Is the GC content value '36.49%' correct for Erysipelothrix rhusiopathiae? (y/n) n
# DOI: 32284671
# Is the GC content value '65.30%' correct for Pseudarthrobacter phenanthrenivorans? (y/n) n
# DOI: 32228807
# Is the GC content value '99.72%' correct for Allium fistulosum? (y/n) n
# DOI: 31961776
# Is the GC content value '5%' correct for n? (y/n) n
# DOI: 31890783
# Is the GC content value '57%' correct for Acidobacteria? (y/n) n
# DOI: 31667287
# Is the GC content value '35.23%' correct for Bacillus? (y/n) n
# DOI: 30949346
# Is the GC content value '93.2%' correct for Dielma fastidiosa? (y/n) n
# DOI: 30944809
# Is the GC content value '46.5%' correct for Bacillus velezensis? (y/n)
# Invalid input. Please enter 'y' or 'n': n
# DOI: 30863388
# Is the GC content value '55%' correct for Agaricus bisporus.? (y/n) n
# DOI: 30761333
# Is the GC content value '53%' correct for Alteromonadales bacterium? (y/n) n
# DOI: 30581420
# Is the GC content value '94%' correct for Methanococcus maripaludis? (y/n) n
# DOI: 30544654
# Is the GC content value '89.81%' correct for Mauritia flexuosa? (y/n) n
# No abstract available
# DOI: 30210484
# Is the GC content value '62.9%' correct for Xanthomonas euvesicatoria? (y/n) n
# DOI: 29692905
# Is the GC content value '72.42%' correct for 'Cellulomonas timonensis'? (y/n) n
# DOI: 29422788
# Is the GC content value '58.7%' correct for Acidovorax citrulli? (y/n) n
# DOI: 28982992
# Is the GC content value '70.5%' correct for Methylobacterium radiotolerans? (y/n) n
# DOI: 28459051
# Is the GC content value '75%' correct for Enterococcus, Staphylococcus, Streptococcus, Serratia, Klebsiella? (y/n) n
# DOI: 28336601
# Is the GC content value '39.6%' correct for Lactobacillus murinus? (y/n) n
# DOI: 28053703
# Is the GC content value '92%' correct for Rubeoparvulum massiliense? (y/n) n

# %%
#37007514  Here are multiple percentage values. It took the wrong percentage value. 
#36386637  Here are multiple percentage values. It seems that it took the wrong gc content value
#35698247  Here are multiple percentage values. Learning: If before a "%" and a "digit" there is a "to", dont take the value. Example: "1 to 5%"
#35695838  Here are multiple percentage values. It seems that it took the wrong gc content value.
#35392139  Here are multiple percentage values. It seems that it took the wrong gc content value.
#Idea: Abstract should content the words gc and content. 
#Idea: content should be appear before the percantage in the abstract OR after a percentage following options should appear G + C content OR GC Content OR GC-Content or content ...(all the different options to write gc content)

# %%
# Following has been changed compared to the code above: It only gives me out a bacteria and gc content value, if the abstract only contains exactly one percentage value.

from Bio import Entrez
import re

Entrez.email = "emirhan.acikgoez@hotmail.com"  # Always tell NCBI who you are

# Search PubMed for articles with "GC-content" in the title
abstracts_with_gc = []
for i in range(0, 200, 20):
    handle = Entrez.esearch(db="pubmed", term="GC AND content AND bacterial[Title]", retstart=i, retmax=20)
    record = Entrez.read(handle)
    ids = record["IdList"]
    # Process the IDs

    # Get the list of article IDs
    article_ids = record["IdList"]

    # Fetch the abstracts for the articles
    handle = Entrez.efetch(db="pubmed", id=article_ids, rettype="abstract")
    records = Entrez.read(handle)

    # Parse the abstracts
    for record in records["PubmedArticle"]:
        try:
            temp_record = record["MedlineCitation"]["Article"]
            abstract = temp_record["Abstract"]["AbstractText"][0]
            gc_matches = re.findall(r"([\d\.]+\%)", abstract)
            bacterial_match = re.search(r"<i>(.*?)</i>", abstract)
            doi = record['PubmedData']['ArticleIdList'][0] if 'ArticleIdList' in record['PubmedData'] else 'N/A'
            if len(gc_matches) == 1 and bacterial_match:
                gc_content = gc_matches[0]
                bacterial_name = bacterial_match.group(1)
                # Prompt the user to input whether the GC content value is correct or not
                print(f"DOI: {doi}")
                correct = input(f"Is the GC content value '{gc_content}' correct for {bacterial_name}? (y/n) ")
                while correct.lower() not in ['y', 'n']:
                    correct = input("Invalid input. Please enter 'y' or 'n': ")
                if correct.lower() == 'y':
                    abstracts_with_gc.append((bacterial_name, gc_content))
        except KeyError:
            print("No abstract available")

# Print the bacterial names and their corresponding GC content percentages
for bacterial_name, gc_content in abstracts_with_gc:
    print(f"{bacterial_name} has a GC content of {gc_content}")
# Out:
# DOI: 35330182
# Is the GC content value '7.4%' correct for E. coli? (y/n) n
# DOI: 35095268
# Is the GC content value '39.09%' correct for Oceanobacillus jordanicus? (y/n) y
# DOI: 34598657
# Is the GC content value '63.7%' correct for Xanthomonas oryzae? (y/n) y
# DOI: 34311561
# Is the GC content value '41.41%' correct for Bacillus? (y/n) y
# DOI: 34168882
# Is the GC content value '98.32%' correct for . Neobacillus massiliamazoniensis? (y/n) n
# DOI: 33847553
# Is the GC content value '46.6%' correct for Schleiferiaceae? (y/n) n
# DOI: 33707334
# Is the GC content value '71.80%' correct for Streptomyces? (y/n) y
# DOI: 33033124
# Is the GC content value '46%' correct for Paenibacillus? (y/n) y
# DOI: 32840429
# Is the GC content value '56.16%' correct for Enterobacter roggenkampii? (y/n) y
# DOI: 32284671
# Is the GC content value '65.30%' correct for Pseudarthrobacter phenanthrenivorans? (y/n) y
# DOI: 32228807
# Is the GC content value '99.72%' correct for Allium fistulosum? (y/n) n
# DOI: 31667287
# Is the GC content value '35.23%' correct for Bacillus? (y/n) y
# DOI: 30581420
# Is the GC content value '94%' correct for Methanococcus maripaludis? (y/n) n
# No abstract available
# DOI: 29692905
# Is the GC content value '72.42%' correct for 'Cellulomonas timonensis'? (y/n) y
# DOI: 29422788
# Is the GC content value '58.7%' correct for Acidovorax citrulli? (y/n) y
# DOI: 28982992
# Is the GC content value '70.5%' correct for Methylobacterium radiotolerans? (y/n) y
# DOI: 28459051
# Is the GC content value '75%' correct for Enterococcus, Staphylococcus, Streptococcus, Serratia, Klebsiella? (y/n) n
# DOI: 28336601
# Is the GC content value '39.6%' correct for Lactobacillus murinus? (y/n) y
# Oceanobacillus jordanicus has a GC content of 39.09%
# Xanthomonas oryzae has a GC content of 63.7%
# Bacillus has a GC content of 41.41%
# Streptomyces has a GC content of 71.80%
# Paenibacillus has a GC content of 46%
# Enterobacter roggenkampii has a GC content of 56.16%
# Pseudarthrobacter phenanthrenivorans has a GC content of 65.30%
# Bacillus has a GC content of 35.23%
# 'Cellulomonas timonensis' has a GC content of 72.42%
# Acidovorax citrulli has a GC content of 58.7%
# Methylobacterium radiotolerans has a GC content of 70.5%
# Lactobacillus murinus has a GC content of 39.6%

# %%
# 35330182 Is not correct gc content value of mentioned bacteria
# 35095268 Seems to be correct
# 34598657 Seems to be correct
# 34311561 Seems to be correct
# 34168882 !!!Contains more than one percentage value. It took the wrong one.!!!
# 33847553 !!!Contains more than one percentage value. It took the wrong one.!!!
# 33707334 seems correct
# 33033124 seems correct
# 32840429 seems correct
# 32284671 seems correct
# 32228807 Contains more than one percentage value. It took the wrong one.
# 31667287 seems correct
# 30581420 Just one percantage value but is wrong value
# 29692905 seems correct
# 29422788
# 28982992 seems correct
# 28459051 seems wrong
# 28336601 seems correct

# %%
## Adjusted code: Since above code had results in which there were more than one GC-content value, we have adjusted the code, so that it only should give out results, in which there is exactly one percentage value
from Bio import Entrez
import re

Entrez.email = "emirhan.acikgoez@hotmail.com"  # Always tell NCBI who you are

# Search PubMed for articles with "GC-content" in the title
abstracts_with_gc = []
for i in range(0, 200, 20):
    handle = Entrez.esearch(db="pubmed", term="GC AND content AND bacterial[Title]", retstart=i, retmax=20)
    record = Entrez.read(handle)
    ids = record["IdList"]
    # Process the IDs

    # Get the list of article IDs
    article_ids = record["IdList"]

    # Fetch the abstracts for the articles
    handle = Entrez.efetch(db="pubmed", id=article_ids, rettype="abstract")
    records = Entrez.read(handle)

    # Parse the abstracts
    for record in records["PubmedArticle"]:
        try:
            temp_record = record["MedlineCitation"]["Article"]
            abstract = temp_record["Abstract"]["AbstractText"][0]
            gc_matches = re.findall(r"([\d\.]+\%)", abstract)
            bacterial_match = re.search(r"<i>(.*?)</i>", abstract)
            doi = record['PubmedData']['ArticleIdList'][0] if 'ArticleIdList' in record['PubmedData'] else 'N/A'
            if len(gc_matches) == 1 and bacterial_match and len(re.findall(r"([\d\.]+\%)", abstract)) == 1:
                gc_content = gc_matches[0]
                bacterial_name = bacterial_match.group(1)
                # Prompt the user to input whether the GC content value is correct or not
                print(f"DOI: {doi}")
                correct = input(f"Is the GC content value '{gc_content}' correct for {bacterial_name}? (y/n) ")
                while correct.lower() not in ['y', 'n']:
                    correct = input("Invalid input. Please enter 'y' or 'n': ")
                if correct.lower() == 'y':
                    abstracts_with_gc.append((bacterial_name, gc_content))
        except KeyError:
            print("No abstract available")

# Print the bacterial names and their corresponding GC content percentages
for bacterial_name, gc_content in abstracts_with_gc:
    print(f"{bacterial_name} has a GC content of {gc_content}")
# Out:
# DOI: 35330182
# Is the GC content value '7.4%' correct for E. coli? (y/n) n
# DOI: 35095268
# Is the GC content value '39.09%' correct for Oceanobacillus jordanicus? (y/n) y
# DOI: 34598657
# Is the GC content value '63.7%' correct for Xanthomonas oryzae? (y/n) y
# DOI: 34311561
# Is the GC content value '41.41%' correct for Bacillus? (y/n) y
# DOI: 34168882
# Is the GC content value '98.32%' correct for . Neobacillus massiliamazoniensis? (y/n) n
# DOI: 33847553
# Is the GC content value '46.6%' correct for Schleiferiaceae? (y/n) n
# DOI: 33707334
# Is the GC content value '71.80%' correct for Streptomyces? (y/n) y
# DOI: 33033124
# Is the GC content value '46%' correct for Paenibacillus? (y/n) y
# DOI: 32840429
# Is the GC content value '56.16%' correct for Enterobacter roggenkampii? (y/n) y
# DOI: 32284671
# Is the GC content value '65.30%' correct for Pseudarthrobacter phenanthrenivorans? (y/n) y
# DOI: 32228807
# Is the GC content value '99.72%' correct for Allium fistulosum? (y/n) n
# DOI: 31667287
# Is the GC content value '35.23%' correct for Bacillus? (y/n) y
# DOI: 30581420
# Is the GC content value '94%' correct for Methanococcus maripaludis? (y/n) n
# No abstract available
# DOI: 29692905
# Is the GC content value '72.42%' correct for 'Cellulomonas timonensis'? (y/n) y
# DOI: 29422788
# Is the GC content value '58.7%' correct for Acidovorax citrulli? (y/n) n
# DOI: 28982992
# Is the GC content value '70.5%' correct for Methylobacterium radiotolerans? (y/n) y
# DOI: 28459051
# Is the GC content value '75%' correct for Enterococcus, Staphylococcus, Streptococcus, Serratia, Klebsiella? (y/n) n
# DOI: 28336601
# Is the GC content value '39.6%' correct for Lactobacillus murinus? (y/n) y
# Oceanobacillus jordanicus has a GC content of 39.09%
# Xanthomonas oryzae has a GC content of 63.7%
# Bacillus has a GC content of 41.41%
# Streptomyces has a GC content of 71.80%
# Paenibacillus has a GC content of 46%
# Enterobacter roggenkampii has a GC content of 56.16%
# Pseudarthrobacter phenanthrenivorans has a GC content of 65.30%
# Bacillus has a GC content of 35.23%
# 'Cellulomonas timonensis' has a GC content of 72.42%
# Methylobacterium radiotolerans has a GC content of 70.5%
# Lactobacillus murinus has a GC content of 39.6%

# %%
# 35330182 seems to be wrong percentage value
# 35095268 seems to be correct percentage value
# 34598657 seems to be correct value
# 34311561 seems to be correct value
# 34168882 more than one percentage value - took the wrong value. Correct value is stated in mol%
##Important idea## It seems that GC-contents are sometimes declared as mol%
# 34168882 more than one percentage value - took the wrong value. Correct value is stated in mol%
# 33847553 more than one percentage value - took the wrong value. !!!mol% value refers here to another bacteria. 
# 33707334 seems to be correct value
# 33033124 seems to be correct value
# 32840429 seems to be correct value
# 32284671 seems to be coorect value
# 32228807 !!! It contains different? bacteria und differet values. It assigned the wrong value to Allium fistulosum (which is actually not a bacteria)
#!!! Allium fistulosum is not a bacteria. It is a species of perennial onion, also known as Welsh onion, which is commonly used as a culinary herb
# 31667287 seems to be correct value
# 30581420 it just has one percentage value but it is not the gc-content value of the bacteria
# 29692905 seems to be coorect value. Check, what bp long means? Some gc-content values are specified as such
# 29422788 not clear, whether assigned gc-content value is correct (rather belongs to Acidovorax citrulli)
# 28982992 correct
# 28459051  does not contain any gc-content value. It just contains multiple bacteria and one percentage value
# 28336601 correct

# %%
# Idea: Search with regex for (C or c) content of  OR abstract should contain mol%

# %%
from Bio import Entrez
import re

Entrez.email = "emirhan.acikgoez@hotmail.com"  # Always tell NCBI who you are

# Search PubMed for articles with "GC-content" in the title
abstracts_with_percentages = []
for i in range(0, 200, 20):
    handle = Entrez.esearch(db="pubmed", term="((C OR c) AND (content of)) OR mol% AND bacteria[Title]", retstart=i, retmax=20)
    record = Entrez.read(handle)
    ids = record["IdList"]
    # Process the IDs

    # Get the list of article IDs
    article_ids = record["IdList"]

    # Fetch the abstracts for the articles
    handle = Entrez.efetch(db="pubmed", id=article_ids, rettype="abstract")
    records = Entrez.read(handle)

    # Parse the abstracts
    for record in records["PubmedArticle"]:
        try:
            temp_record = record["MedlineCitation"]["Article"]
            abstract = temp_record["Abstract"]["AbstractText"][0]
            percentage_matches = re.findall(r"([\d\.]+\%)", abstract)
            if len(percentage_matches) == 1:
                percentage_value = percentage_matches[0]
                if ("content of" in abstract.lower() or "mol%" in abstract.lower()):
                    bacterial_match = re.search(r"<i>(.*?)</i>", abstract)
                    doi = record['PubmedData']['ArticleIdList'][0] if 'ArticleIdList' in record['PubmedData'] else 'N/A'
                    if bacterial_match:
                        bacterial_name = bacterial_match.group(1)
                        # Prompt the user to input whether the percentage value is correct or not
                        print(f"DOI: {doi}")
                        correct = input(f"Is the percentage value '{percentage_value}' correct for {bacterial_name}? (y/n) ")
                        while correct.lower() not in ['y', 'n']:
                            correct = input("Invalid input. Please enter 'y' or 'n': ")
                        if correct.lower() == 'y':
                            abstracts_with_percentages.append((bacterial_name, percentage_value))
        except KeyError:
            print("No abstract available")

# Print the bacterial names and their corresponding percentage values
for bacterial_name, percentage_value in abstracts_with_percentages:
    print(f"{bacterial_name} has a {percentage_value} value")

# %%
## Adjusted code: Since above code had results in which there were more than one GC-content value, we have adjusted the code, so that it only should give out results, in which there is exactly one percentage value
from Bio import Entrez
import re

Entrez.email = "emirhan.acikgoez@hotmail.com"  # Always tell NCBI who you are

# Search PubMed for articles with "GC-content" in the title
abstracts_with_gc = []
for i in range(0, 200, 20):
    handle = Entrez.esearch(db="pubmed", term="((C OR c) AND (content of)) OR mol% AND bacteria[Title]", retstart=i, retmax=20)
    record = Entrez.read(handle)
    ids = record["IdList"]
    # Process the IDs

    # Get the list of article IDs
    article_ids = record["IdList"]

    # Fetch the abstracts for the articles
    handle = Entrez.efetch(db="pubmed", id=article_ids, rettype="abstract")
    records = Entrez.read(handle)

    # Parse the abstracts
    for record in records["PubmedArticle"]:
        try:
            temp_record = record["MedlineCitation"]["Article"]
            abstract = temp_record["Abstract"]["AbstractText"][0]
            gc_matches = re.findall(r"([\d\.]+\%)", abstract)
            bacterial_match = re.search(r"<i>(.*?)</i>", abstract)
            doi = record['PubmedData']['ArticleIdList'][0] if 'ArticleIdList' in record['PubmedData'] else 'N/A'
            if len(gc_matches) == 1 and bacterial_match and len(re.findall(r"([\d\.]+\%)", abstract)) == 1:
                gc_content = gc_matches[0]
                bacterial_name = bacterial_match.group(1)
                # Prompt the user to input whether the GC content value is correct or not
                print(f"DOI: {doi}")
                correct = input(f"Is the GC content value '{gc_content}' correct for {bacterial_name}? (y/n) ")
                while correct.lower() not in ['y', 'n']:
                    correct = input("Invalid input. Please enter 'y' or 'n': ")
                if correct.lower() == 'y':
                    abstracts_with_gc.append((bacterial_name, gc_content))
        except KeyError:
            print("No abstract available")

# Print the bacterial names and their corresponding GC content percentages
for bacterial_name, gc_content in abstracts_with_gc:
    print(f"{bacterial_name} has a GC content of {gc_content}")
# Out:
# DOI: 36767220
# Is the GC content value '0.5%' correct for Brad rhizobium japonicum? (y/n) n
# DOI: 36748432
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14628\3298627929.py in <module>
#      33                 # Prompt the user to input whether the GC content value is correct or not
#      34                 print(f"DOI: {doi}")
# ---> 35                 correct = input(f"Is the GC content value '{gc_content}' correct for {bacterial_name}? (y/n) ")
#      36                 while correct.lower() not in ['y', 'n']:
#      37                     correct = input("Invalid input. Please enter 'y' or 'n': ")
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# 36767220 false

# %%
from Bio import Entrez
import re

Entrez.email = "emirhan.acikgoez@hotmail.com"  # Always tell NCBI who you are

# Search PubMed for articles with "GC-content" in the title
abstracts_with_gc = []
for i in range(0, 200, 20):
    handle = Entrez.esearch(db="pubmed", term="((C OR c) AND (content of)) OR mol% AND bacteria[Title]", retstart=i, retmax=20)
    record = Entrez.read(handle)
    ids = record["IdList"]
    # Process the IDs

    # Get the list of article IDs
    article_ids = record["IdList"]

    # Fetch the abstracts for the articles
    handle = Entrez.efetch(db="pubmed", id=article_ids, rettype="abstract")
    records = Entrez.read(handle)

    # Parse the abstracts
    for record in records["PubmedArticle"]:
        try:
            temp_record = record["MedlineCitation"]["Article"]
            abstract = temp_record["Abstract"]["AbstractText"][0]
            gc_match = re.search(r"([\d\.]+\%)", abstract)
            bacterial_match = re.search(r"<i>(.*?)</i>", abstract)
            doi = record['PubmedData']['ArticleIdList'][0] if 'ArticleIdList' in record['PubmedData'] else 'N/A'
            if gc_match and bacterial_match:
                gc_content = gc_match.group(1)
                bacterial_name = bacterial_match.group(1)
                # Prompt the user to input whether the GC content value is correct or not
                print(f"DOI: {doi}")
                correct = input(f"Is the GC content value '{gc_content}' correct for {bacterial_name}? (y/n) ")
                while correct.lower() not in ['y', 'n']:
                    correct = input("Invalid input. Please enter 'y' or 'n': ")
                if correct.lower() == 'y':
                    abstracts_with_gc.append((bacterial_name, gc_content))
        except KeyError:
            print("No abstract available")

# Print the bacterial names and their corresponding GC content percentages
for bacterial_name, gc_content in abstracts_with_gc:
    print(f"{bacterial_name} has a GC content of {gc_content}")
# Out:
# DOI: 36982580
# Is the GC content value '99.6%' correct for E. coli? (y/n) n
# DOI: 36902440

# %%
# 36982580 more than one gc content, took the wrong one
36902440

# %%
from Bio import Entrez
import re

Entrez.email = "emirhan.acikgoez@hotmail.de"  # Always tell NCBI who you are

abstracts_with_one_perc = []

# Search PubMed for articles with "GC-content" in the title
for i in range(0, 200, 20):
    handle = Entrez.esearch(db="pubmed", term="GC content bacterial[Title]", retstart=i, retmax=20)
    record = Entrez.read(handle)
    ids = record["IdList"]
    # Process the IDs

    # Get the list of article IDs
    article_ids = record["IdList"]

    # Fetch the abstracts for the articles
    handle = Entrez.efetch(db="pubmed", id=article_ids, rettype="abstract")
    records = Entrez.read(handle)

    # Print the abstracts
    noAbstract = 0
    for record in records["PubmedArticle"]:
        try:
            temp_record = record["MedlineCitation"]["Article"]
            abstract = temp_record["Abstract"]["AbstractText"][0]
            matches = re.findall(r"\%", abstract)
            if len(matches) == 1 and ("mol%" in abstract or "content of" in abstract):
                abstracts_with_one_perc.append(temp_record)
        except KeyError:
            print("No abstract available")
            noAbstract += 1
    print("No abstract available for " + str(noAbstract) + " articles "  + "by total of " + str(len(article_ids)) + " articles")

hopeful_dicts = []

# give the one <i> tag which is the nearest to the % sign
# Add DOI to the dict
# Add Abstract to the dict

for pre_x in abstracts_with_one_perc:
    x = pre_x["Abstract"]["AbstractText"][0]

    # Extract the content between the tags
    result = re.search(r"<i>(.*?)</i>", x)
    if result:
        bacteria = result.group(1)
    else:
        bacteria = None

    # Extract the percentage value
    result = re.search(r"([\d\.]+\%)", x)
    if result:
        gc_content = result.group(1)
    else:
        gc_content = None

    # Get the DOI number of the article
    doi = pre_x["ArticleIdList"][0] if "ArticleIdList" in pre_x else None

    is_valuable_data = ""
    print("Is the GC-content value for " + str(bacteria) + " with " + str(gc_content) + " correct? (y/n/m)")
    while is_valuable_data not in ("y", "n", "m"):
        is_valuable_data = input("Is the GC-content value for " + str(bacteria) + " with " + str(gc_content) + " correct? (y/n/m)")

    hopeful_dict = {"bacteria": bacteria, "gc_content": gc_content, "doi": doi, "is_valuable_data": is_valuable_data}

    hopeful_dicts.append(hopeful_dict)

# Show only dicts with a value and a key
hopeful_dicts = [x for x in hopeful_dicts if x["bacteria"] is not None and x["gc_content"] is not None and x["doi"] is not None]
print(hopeful_dicts)
# Out:
# No abstract available for 0 articles by total of 20 articles
# No abstract available
# No abstract available for 1 articles by total of 20 articles
# No abstract available for 0 articles by total of 20 articles
# No abstract available for 0 articles by total of 20 articles
# No abstract available for 0 articles by total of 20 articles
# No abstract available for 0 articles by total of 20 articles
# No abstract available for 0 articles by total of 20 articles
# No abstract available for 0 articles by total of 20 articles
# No abstract available for 0 articles by total of 20 articles
# No abstract available
# No abstract available for 1 articles by total of 20 articles
# Is the GC-content value for None with 43.88% correct? (y/n/m)
# Is the GC-content value for None with 43.88% correct? (y/n/m)n
# Is the GC-content value for None with 51.68% correct? (y/n/m)
# Is the GC-content value for None with 51.68% correct? (y/n/m)n
# Is the GC-content value for Martelella soudanensis with None correct? (y/n/m)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12284\1594029790.py in <module>
#      63     print("Is the GC-content value for " + str(bacteria) + " with " + str(gc_content) + " correct? (y/n/m)")
#      64     while is_valuable_data not in ("y", "n", "m"):
# ---> 65         is_valuable_data = input("Is the GC-content value for " + str(bacteria) + " with " + str(gc_content) + " correct? (y/n/m)")
#      66
#      67     hopeful_dict = {"bacteria": bacteria, "gc_content": gc_content, "doi": doi, "is_valuable_data": is_valuable_data}
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
